# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://thespotgym.com/gym-occupancy'
URL2 = 'https://portal.rockgympro.com/portal/public/415a34a23151c6546419c1415d122b61/occupancy?&iframeid=occupancyCounter&fId=1038'
page = requests.get(URL2)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="facility-count")

# %%
print(results.prettify())
# Out:
# <div id="facility-count">
#  <span id="count" style="display:inline">
#  </span>
#  <span id="capacity" style="display:inline">
#  </span>
#  <span id="visitor" style="display:inline">
#  </span>
# </div>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Facility Counter</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
# <script src="/portal/js/gauge.min.js"></script>
# <style>
#
#         body {
#             font-family: Arial, sans-serif;
#             color: black;
#             background-color: #FFFFFF;
#         }
#
#         #main-gauge {
#
#             width: 250px;
#             height: 100px;
#             margin-left: auto;
#             margin-right: auto;
#             text-align: center;
#         }
#
#         #header-label {
#             font-size: medium;
#             margin-bottom: 5px;
#         }
#
#         #facility-sub-label {
#             font-size: medium;
#             margin-bottom: 10px;
#         }
#
#         #facility-count {
#             font-size: large;
#             text-align: center;
#         }
#
#         #gauge {
#             width: 248px;
# ...

# %%
from selenium.webdriver import Chrome, Firefox
from selenium.webdriver.firefox.options import Options
opts = Options()
opts.set_headless()
assert opts.headless  # Operating in headless mode
# Out:
# /var/folders/3n/yqn87g896kg2zzfpydnwl9q00000gn/T/ipykernel_39774/1481610945.py:4: DeprecationWarning: use setter for headless property instead of set_headless
#   opts.set_headless()

# %%
import time

# %%
# this works
browser = Firefox(options=opts, executable_path=r'/Users/tyler/code/random/climbing/geckodriver')
# browser = Firefox(executable_path=r'/Users/tyler/code/random/climbing/geckodriver')
# browser.get('https://thespotgym.com/gym-occupancy')
browser.get(r'https://portal.rockgympro.com/portal/public/415a34a23151c6546419c1415d122b61/occupancy?&iframeid=occupancyCounter&fId=1038')
time.sleep(5.0)
soup = BeautifulSoup(browser.page_source)
print('checking for count...')
elements = soup.find_all("div", id="facility-count")
print(elements[0].find_all("span", id="count")[0].text)
browser.close()
# Out:
# checking for count...
# 22

# %%
browser = Firefox(executable_path=r'/Users/tyler/code/random/climbing/geckodriver')
# browser.get('https://thespotgym.com/gym-occupancy')
browser.get(r'https://portal.rockgympro.com/portal/public/415a34a23151c6546419c1415d122b61/occupancy?&iframeid=occupancyCounter&fId=1038')

# %%
soup = BeautifulSoup(browser.page_source)
print(soup.prettify())
# Out:
# <html class="yui3-js-enabled js-focus-visible js flexbox canvas canvastext webgl no-touch hashchange history draganddrop rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients no-cssreflections csstransforms no-csstransforms3d csstransitions video audio svg inlinesvg svgclippaths wf-futurapt-n7-active wf-hypatiasanspro-n7-active wf-futurapt-n6-active wf-tradegothicnextsoftrounded-n4-active wf-futurapt-i4-active wf-eurostileextended-n5-active wf-futurapt-n3-active wf-futurapt-n5-active wf-futurapt-i7-active wf-futurapt-n4-active wf-hypatiasanspro-n4-active wf-active" data-js-focus-visible="" lang="en-US" style="" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <div id="yui3-css-stamp" style="position: absolute !important; visibility: hidden !important">
#  </div>
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# ...

# %%
browser.close()

# %%
browser = Firefox(executable_path=r'/Users/tyler/code/random/climbing/geckodriver')
# browser.get('https://thespotgym.com/gym-occupancy')
browser.get(r'https://portal.rockgympro.com/portal/public/415a34a23151c6546419c1415d122b61/occupancy?&iframeid=occupancyCounter&fId=1038')

# %%
# browser.get('https://thespotgym.com/gym-occupancy')
browser.get(r'https://portal.rockgympro.com/portal/public/415a34a23151c6546419c1415d122b61/occupancy?&iframeid=occupancyCounter&fId=1038')
# thing = browser.find_element_by_id('facility-count')

# %%
browser.find_element_by_id()
# Out:
# Signature:  browser.find_element_by_id(id_)
# Docstring:
# Finds an element by id.
#
# :Args:
#  - id\_ - The id of the element to be found.
#
# :Returns:
#  - WebElement - the element if it was found
#
# :Raises:
#  - NoSuchElementException - if the element wasn't found
#
# :Usage:
#     element = driver.find_element_by_id('foo')
# File:      ~/opt/anaconda3/envs/Climb/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py
# Type:      method

# %%
thing = browser.find_element_by_id('occupancyCounter')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 thing = browser.find_element_by_id('occupancyCounter')
#
# File ~/opt/anaconda3/envs/Climb/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:360, in WebDriver.find_element_by_id(self, id_)
#     345 def find_element_by_id(self, id_):
#     346     """Finds an element by id.
#     347
#     348     :Args:
#    (...)
#     358         element = driver.find_element_by_id('foo')
#     359     """
# --> 360     return self.find_element(by=By.ID, value=id_)
#
# File ~/opt/anaconda3/envs/Climb/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
# ...

# %%
browser.close()

# %%
soup = BeautifulSoup(browser.page_source)

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Facility Counter
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script src="https://code.jquery.com/jquery-1.12.4.min.js">
#   </script>
#   <script src="/portal/js/gauge.min.js">
#   </script>
#   <style>
#    body {
#             font-family: Arial, sans-serif;
#             color: black;
#             background-color: #FFFFFF;
#         }
#
#         #main-gauge {
#
#             width: 250px;
#             height: 100px;
#             margin-left: auto;
#             margin-right: auto;
#             text-align: center;
#         }
#
#         #header-label {
#             font-size: medium;
#             margin-bottom: 5px;
#         }
#
#         #facility-sub-label {
#             font-size: medium;
#             margin-bottom: 10px;
#         }
#
#         #facility-count {
#             font-size: large;
#             text-align: center;
#         }
#
#         #gauge {
# ...

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Facility Counter
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script src="https://code.jquery.com/jquery-1.12.4.min.js">
#   </script>
#   <script src="/portal/js/gauge.min.js">
#   </script>
#   <style>
#    body {
#             font-family: Arial, sans-serif;
#             color: black;
#             background-color: #FFFFFF;
#         }
#
#         #main-gauge {
#
#             width: 250px;
#             height: 100px;
#             margin-left: auto;
#             margin-right: auto;
#             text-align: center;
#         }
#
#         #header-label {
#             font-size: medium;
#             margin-bottom: 5px;
#         }
#
#         #facility-sub-label {
#             font-size: medium;
#             margin-bottom: 10px;
#         }
#
#         #facility-count {
#             font-size: large;
#             text-align: center;
#         }
#
#         #gauge {
# ...

# %%
soup.find_by_id(id='facility-count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 soup.find_by_id(id='facility-count')
#
# TypeError: 'NoneType' object is not callable

# %%
elements = soup.find_all("div", id="facility-count")

# %%
elements[0].find_all("span", id="count")[0].text
# Out:
# '31'
